# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Загрузим данные

# %%
train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')

# %% [markdown]
# ## Соединим оба датафрейма

# %%
df = pd.concat([train, test], ignore_index=True, sort = False)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12970 entries, 0 to 12969
# Data columns (total 24 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   PassengerId   12970 non-null  object
#  1   CryoSleep     12660 non-null  object
#  2   Cabin         12970 non-null  object
#  3   Destination   12696 non-null  object
#  4   Age           12700 non-null  float64
#  5   VIP           12674 non-null  object
#  6   RoomService   12707 non-null  float64
#  7   FoodCourt     12681 non-null  float64
#  8   ShoppingMall  12664 non-null  float64
#  9   Spa           12686 non-null  float64
#  10  VRDeck        12702 non-null  float64
#  11  Name          12970 non-null  object
#  12  Transported   8693 non-null   object
#  13  Group         12970 non-null  object
#  14  Num_gr        12970 non-null  object
#  15  HomePlanet    12813 non-null  object
#  16  Deck          12970 non-null  object
#  17  Num_cb        12970 non-null  object
#  18  Side          12970 non-null  object
#  19  Name_1        12970 non-null  object
#  20  Name_2        12970 non-null  object
#  21  Name_len      12970 non-null  int64
#  22  Name_1_len    12970 non-null  int64
#  23  Name_2_len    12970 non-null  int64
# dtypes: float64(6), int64(3), object(15)
# memory usage: 3.0+ MB

# %% [markdown]
# ### Колонка "Transported" - целевая переменная. Проведем ее анализ

# %%
sns.set_style('whitegrid')
sns.countplot(x='Transported',data=df);

# %%
print('Проценты значений целевой переменной:')
df['Transported'].value_counts(normalize=True, ascending=True)*100
# Out:
# Проценты значений целевой переменной:
# False    49.637639
# True     50.362361
# Name: Transported, dtype: float64

# %% [markdown]
# ### Имеем сбалансированную целевую переменную.

# %% [markdown]
# ## Посмотрим, насколько уникальные признаки

# %%
df.nunique()
# Out:
# PassengerId     12970
# CryoSleep           2
# Cabin            9826
# Destination         3
# Age                80
# VIP                 2
# RoomService      1578
# FoodCourt        1953
# ShoppingMall     1367
# Spa              1679
# VRDeck           1642
# Name            12630
# Transported         2
# Group            9280
# Num_gr              8
# HomePlanet          3
# Deck                9
# Num_cb           1894
# Side                3
# Name_1           2884
# Name_2           2407
# Name_len           12
# Name_1_len          5
# Name_2_len          9
# dtype: int64

# %% [markdown]
# ### Посмотрим на корреляцию и описание числовых переменных

# %%
df.corr()
# Out:
#                    Age  RoomService  FoodCourt  ShoppingMall       Spa  \
# Age           1.000000     0.067300   0.124447      0.034959  0.118992
# RoomService   0.067300     1.000000  -0.020146      0.057402  0.008936
# FoodCourt     0.124447    -0.020146   1.000000     -0.001589  0.228990
# ShoppingMall  0.034959     0.057402  -0.001589      1.000000  0.010504
# Spa           0.118992     0.008936   0.228990      0.010504  1.000000
# VRDeck        0.101441    -0.023847   0.244279      0.004485  0.149874
#
#                 VRDeck
# Age           0.101441
# RoomService  -0.023847
# FoodCourt     0.244279
# ShoppingMall  0.004485
# Spa           0.149874
# VRDeck        1.000000

# %%
plt.figure(figsize=(10,6))
sns.heatmap(df.corr(),annot=True,cmap='coolwarm',fmt='.2f')
plt.title('Correlation heatmap for numerical features');

# %%
df.describe()
# Out:
#                 Age   RoomService     FoodCourt  ShoppingMall           Spa  \
# count  12700.000000  12707.000000  12681.000000  12664.000000  12686.000000
# mean      28.771969    222.897852    451.961675    174.906033    308.476904
# std       14.387261    647.596664   1584.370747    590.558690   1130.279641
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%       19.000000      0.000000      0.000000      0.000000      0.000000
# 50%       27.000000      0.000000      0.000000      0.000000      0.000000
# 75%       38.000000     49.000000     77.000000     29.000000     57.000000
# max       79.000000  14327.000000  29813.000000  23492.000000  22408.000000
#
#              VRDeck
# count  12702.000000
# mean     306.789482
# std     1180.097223
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%       42.000000
# max    24133.000000

# %% [markdown]
# # СДЕЛАТЬ: Создать дискретную пер-ю возраста

# %%
plt.figure(figsize=(7,4), dpi=100)
sns.histplot(data=df, x='Age', kde=True, bins=80, palette='coolwarm', hue='Transported');

# %% [markdown]
# ### Вывод: люди до 18 лет в целом перемещались больше, чем все остальные возраста.

# %%
plt.figure(figsize=(7,4), dpi=100)
sns.histplot(data=df, x='Age', kde=True, bins=80, palette='coolwarm');

# %% [markdown]
# ### Вывод: переменная возраста имеет, скорее всего, Пуассоновское распределение с нулевым завышением (zero-inflated).

# %%
sns.boxplot(data=df, x='Transported', y='Age');

# %% [markdown]
# ### Вывод: распределение значений возрастов между теми, кого переместили и не переместили, практически идентично

# %% [markdown]
# ## Посмотрим, что из себя представляют все остальные числовые переменные

# %%
df['RoomService'].value_counts()
# Out:
# 0.0       8303
# 1.0        185
# 2.0        113
# 3.0         89
# 4.0         71
#           ...
# 263.0        1
# 271.0        1
# 922.0        1
# 3905.0       1
# 652.0        1
# Name: RoomService, Length: 1578, dtype: int64

# %%
sns.histplot(data=df, x='RoomService', kde=True, bins=80);

# %%
# создадим ДФ, где 'RoomService' не равно 0
rs_not0 = df[(df['RoomService'] != 0) & (df['RoomService'] < 100)]

# %%
plt.figure(figsize=(5,3), dpi=100)
sns.histplot(data=rs_not0, x='RoomService', bins=100, hue='Transported', palette='coolwarm');

# %%
plt.figure(figsize=(5,3), dpi=100)
sns.histplot(data=rs_not0, x='RoomService', bins=100);

# %%
df.describe()
# Out:
#                 Age   RoomService     FoodCourt  ShoppingMall           Spa  \
# count  12700.000000  12707.000000  12681.000000  12664.000000  12686.000000
# mean      28.771969    222.897852    451.961675    174.906033    308.476904
# std       14.387261    647.596664   1584.370747    590.558690   1130.279641
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%       19.000000      0.000000      0.000000      0.000000      0.000000
# 50%       27.000000      0.000000      0.000000      0.000000      0.000000
# 75%       38.000000     49.000000     77.000000     29.000000     57.000000
# max       79.000000  14327.000000  29813.000000  23492.000000  22408.000000
#
#              VRDeck
# count  12702.000000
# mean     306.789482
# std     1180.097223
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%       42.000000
# max    24133.000000

# %% [markdown]
# ### Вывод: Смысла исследовать каждую числовую переменную не вижу смысла, тк судя по описанию, они очень похожи. Из проведенного исследования следует, что все числовые переменные, кроме возраста, имеют, скорее всего, отрицательно биномиальное распределение с нулевым завышением (zero-inflated). Поэтому графики с распределением типа Boxplot не имеет смыла строить из-за того, что все значения будут там выбросами.

# %% [markdown]
# ## Рассмотрим наиболее коррелируемые между собой числовые переменные

# %%
plt.figure(figsize=(7,4), dpi=150)
sns.scatterplot(data=df, x='Spa', y='VRDeck', hue='Transported', palette='coolwarm', alpha=0.5);

# %% [markdown]
# ### Вывод: Если рассматривать корреляцию независимых переменных 'Spa' и 'VRDeck', то мы видим, не перенессеные в другое измерение пассажири могут иметь огромный разброс значений этих переменный, а вот в случае перенесенных можем точно сказать, что значения данных переменных находятся в диапозоне от 0 до 5000.

# %%
plt.figure(figsize=(7,4), dpi=150)
sns.scatterplot(data=df, x='FoodCourt', y='VRDeck', hue='Transported', palette='coolwarm', alpha=0.5);

# %% [markdown]
# ### Вывод: мы видим 2 кластера с точками. Причем чем меньше траты на VRDeck, тем чаще пассажир перенесен в другое измерение

# %%
plt.figure(figsize=(7,4), dpi=150)
sns.scatterplot(data=df, x='FoodCourt', y='Spa', hue='Transported', palette='coolwarm', alpha=0.5);

# %% [markdown]
# ### Вывод: мы видим 2 кластера с точками. Причем чем меньше траты на Spa, тем чаще пассажир перенесен в другое измерение

# %%
numeric_df = df.select_dtypes(exclude='object')

# %% [markdown]
# ## Построим график Pairplot

# %%
sns.pairplot(df, vars=['RoomService', 'FoodCourt', 'ShoppingMall', 'Spa', 'VRDeck'], 
             hue='Transported', palette='coolwarm', corner=True);

# %%
fig = plt.figure(figsize=(7,4), dpi=100)
ax = fig.add_subplot(projection='3d')

ax.scatter(df['Spa'], df['VRDeck'], df['FoodCourt'], c=df['Transported']);

# %%
numeric_df.hist(figsize=(16, 16), bins=50, xlabelsize=6, ylabelsize=6);

# %%
df[df['RoomService'] == 0]['VIP'].value_counts()
# Out:
# False    7988
# True      130
# Name: VIP, dtype: int64

# %%
df[df['RoomService'] > 0]['VIP'].value_counts()
# Out:
# False    4161
# True      139
# Name: VIP, dtype: int64

# %%
df['VIP'].value_counts()
# Out:
# False    12401
# True       273
# Name: VIP, dtype: int64

# %%
sns.pairplot(df, vars=['RoomService', 'FoodCourt', 'ShoppingMall', 'Spa', 'VRDeck'], 
             hue='VIP', palette='coolwarm', corner=True);

# %%
categorical_cols = df.select_dtypes(include=['object','category'])

# %%
categorical_cols
# Out:
#       PassengerId HomePlanet CryoSleep     Cabin    Destination    VIP  \
# 0         0001_01     Europa     False     B/0/P    TRAPPIST-1e  False
# 1         0002_01      Earth     False     F/0/S    TRAPPIST-1e  False
# 2         0003_01     Europa     False     A/0/S    TRAPPIST-1e   True
# 3         0003_02     Europa     False     A/0/S    TRAPPIST-1e  False
# 4         0004_01      Earth     False     F/1/S    TRAPPIST-1e  False
# ...           ...        ...       ...       ...            ...    ...
# 12965     9266_02      Earth      True  G/1496/S    TRAPPIST-1e  False
# 12966     9269_01      Earth     False       NaN    TRAPPIST-1e  False
# 12967     9271_01       Mars      True   D/296/P    55 Cancri e  False
# 12968     9273_01     Europa     False   D/297/P            NaN  False
# 12969     9277_01      Earth      True  G/1498/S  PSO J318.5-22  False
#
#                     Name Transported
# 0        Maham Ofracculy       False
# 1           Juanna Vines        True
# 2          Altark Susent       False
# 3           Solam Susent       False
# 4      Willy Santantines        True
# ...                  ...         ...
# 12965        Jeron Peter         NaN
# 12966      Matty Scheron         NaN
# 12967        Jayrin Pore         NaN
# 12968     Kitakan Conale         NaN
# 12969   Lilace Leonzaley         NaN
#
# [12970 rows x 8 columns]

# %%
sns.countplot(data=df, x='HomePlanet', hue='Transported');

# %%
sns.countplot(data=df, x='CryoSleep', hue='Transported');

# %%
sns.countplot(data=df, x='Destination', hue='Transported');

# %%
sns.countplot(data=df, x='VIP', hue='Transported');

# %% [markdown]
# # СД: Выводы насчет зависимостей кат.пер и вообще всех графиков
# # ХХХ
# #### СД: Разбить Кэбин
# # ХХХ
# #### СД: Разбить Нэйм
# # СД: Миссинг Дэйта

# %% [markdown]
# ## Посмотрим на отсутствующие значения

# %%
df.isnull().sum()
# Out:
# PassengerId        0
# CryoSleep        310
# Cabin            299
# Destination      274
# Age              270
# VIP              296
# RoomService      263
# FoodCourt        289
# ShoppingMall     306
# Spa              284
# VRDeck           268
# Name             294
# Transported     4277
# Group              0
# Num_gr             0
# HomePlanet       157
# dtype: int64

# %% [markdown]
# ## Создадим 2 новые колонки на основе колонки 'PassengerId'

# %%
df['Group'] = df['PassengerId'].apply(lambda num: num.split('_')[0])

# %%
df['Num_gr'] = df['PassengerId'].apply(lambda num: num.split('_')[1])

# %% [markdown]
# ## Создадим 3 новые колонки на основе колонки 'Cabin'

# %%
# проверим, есть ли пропущенные данные
df['Cabin'].isna().sum()
# Out:
# 299

# %%
# заполним пропущенные данные значениями 'None/0/None'
df['Cabin'] = df['Cabin'].fillna('None/0/None')

# %%
df['Deck'] = df['Cabin'].apply(lambda num: num.split('/')[0])

# %%
df['Num_cb'] = df['Cabin'].apply(lambda num: num.split('/')[1])

# %%
df['Side'] = df['Cabin'].apply(lambda num: num.split('/')[2])

# %% [markdown]
# ### Построим графики зависимостей целевой переменной и получившихся новых признаков

# %%
sns.countplot(data=df, x='Deck', hue='Transported');

# %%
sns.histplot(data=df, x=df['Num_cb'].astype('float64'))
# Out:
# <AxesSubplot:xlabel='Num_cb', ylabel='Count'>

# %%
sns.countplot(data=df, x='Side', hue='Transported');

# %% [markdown]
# ## Попробуем разбить колонку 'Name' на имя и фамилию

# %%
df['Name'].isna().sum()
# Out:
# 294

# %%
df['Name'] = df['Name'].fillna('None None')

# %%
df['Name_len'].value_counts()
# Out:
# 2    12970
# Name: Name_len, dtype: int64

# %%
df['Name_1'] = df['Name'].apply(lambda name: name.split()[0])
df['Name_2'] = df['Name'].apply(lambda name: name.split()[1])

# %%
df['Name_1'].nunique()
# Out:
# 2884

# %%
df['Name_2'].nunique()
# Out:
# 2407

# %%
df['Name_len'] = df['Name'].str.len()

# %%
sns.countplot(data=df, x='Name_len', hue='Transported');

# %%
df['Name_1_len'] = df['Name_1'].str.len()
df['Name_2_len'] = df['Name_2'].str.len()

# %%
sns.countplot(data=df, x='Name_1_len', hue='Transported');

# %%
sns.countplot(data=df, x='Name_2_len', hue='Transported');

# %%
df['N1_1ch'] = df['Name_1'].apply(lambda name: name[0])
df['N2_1ch'] = df['Name_2'].apply(lambda name: name[0])

# %%
sns.countplot(data=df, x='N1_1ch', hue='Transported');

# %%
sns.countplot(data=df, x='N2_1ch', hue='Transported');

# %% [markdown]
# # Работа с пропущенными значениями

# %%
df.isna().sum()
# Out:
# PassengerId        0
# CryoSleep        310
# Cabin              0
# Destination      274
# Age              270
# VIP              296
# RoomService      263
# FoodCourt        289
# ShoppingMall     306
# Spa              284
# VRDeck           268
# Name               0
# Transported     4277
# Group              0
# Num_gr             0
# HomePlanet       157
# Deck               0
# Num_cb             0
# Side               0
# Name_1             0
# Name_2             0
# Name_len           0
# Name_1_len         0
# Name_2_len         0
# dtype: int64

# %% [markdown]
# ## Колонка 'HomePlanet'

# %% [markdown]
# ### Попробуем заполнить пропущенные значения колонки 'HomePlanet', основываясь на значения новой колонки 'Group', в которой предположительно формируются группы с одной планеты.
# #### Для этого сгруппируем наши данные по колонкам 'Group', 'HomePlanet', используя аггрегирующую функцию count() и выведем результат в виде нового Датафрейма

# %%
df_ghp = df.groupby(['Group', 'HomePlanet'],as_index=False).count()[['Group', 'HomePlanet']]

# %% [markdown]
# ### Гипотеза такова: если группы формируются с одной и той же планеты, то выводя значения колонки 'Group', никаких дубликатов быть не должно. Если будут дубликаты, значит одна и та же группа может формироваться с разных планет. Проверим дубликаты в колонке 'Group'

# %%
df_ghp['Group'].duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### Дубликатов нет, поэтому мы можем новый Датафрейм df_ghp принять как словарь для заполнения пропущенных значений в колонке 'HomePlanet'

# %%
df.groupby(['Group', 'HomePlanet'],as_index=False).count()[['Group', 'HomePlanet', 'PassengerId']]
# Out:
#      Group HomePlanet  PassengerId
# 0     0001     Europa            1
# 1     0002      Earth            1
# 2     0003     Europa            2
# 3     0004      Earth            1
# 4     0005      Earth            1
# ...    ...        ...          ...
# 9119  9276     Europa            1
# 9120  9277      Earth            1
# 9121  9278      Earth            1
# 9122  9279      Earth            1
# 9123  9280     Europa            2
#
# [9124 rows x 3 columns]

# %%
df_ghp
# Out:
#      Group HomePlanet
# 0     0001     Europa
# 1     0002      Earth
# 2     0003     Europa
# 3     0004      Earth
# 4     0005      Earth
# ...    ...        ...
# 9119  9276     Europa
# 9120  9277      Earth
# 9121  9278      Earth
# 9122  9279      Earth
# 9123  9280     Europa
#
# [9124 rows x 2 columns]

# %% [markdown]
# ## Заполним пропущенные значения в колонке 'HomePlanet' значениями словаря df_ghp

# %%
df = pd.merge(df, df_ghp, on=['Group'], how='left').drop('HomePlanet_x',axis=1)

# %%
df = df.rename({'HomePlanet_y': 'HomePlanet'}, axis=1)

# %% [markdown]
# ## Проверим теперь пропущенные значения

# %%
df.isnull().sum()
# Out:
# PassengerId        0
# CryoSleep        310
# Cabin              0
# Destination      274
# Age              270
# VIP              296
# RoomService      263
# FoodCourt        289
# ShoppingMall     306
# Spa              284
# VRDeck           268
# Name               0
# Transported     4277
# Group              0
# Num_gr             0
# HomePlanet       157
# Deck               0
# Num_cb             0
# Side               0
# Name_1             0
# Name_2             0
# Name_len           0
# dtype: int64

# %% [markdown]
# ### В колонке "HomePlanet" было 288 проп.зн., стало 157. Теперь посмотрим, что можно сделать с оставшимися

# %%
df_hp0 = df[df['HomePlanet'].isna()]

# %%
df[df['Group'] == '8417']
# Out:
#       PassengerId CryoSleep     Cabin  Destination   Age    VIP  RoomService  \
# 12542     8417_01     False  F/1617/S  TRAPPIST-1e  43.0  False          0.0
#
#        FoodCourt  ShoppingMall  Spa  VRDeck              Name Transported  \
# 12542        0.0         775.0  0.0    93.0  Luzel Bertsontry         NaN
#
#       Group Num_gr HomePlanet
# 12542  8417     01        NaN

# %%
df_hp0['Destination'].value_counts()
# Out:
# TRAPPIST-1e      113
# 55 Cancri e       27
# PSO J318.5-22     14
# Name: Destination, dtype: int64

# %%
df['Destination'].value_counts()
# Out:
# TRAPPIST-1e      8871
# 55 Cancri e      2641
# PSO J318.5-22    1184
# Name: Destination, dtype: int64

# %%
sns.countplot(data=df, x='Destination', hue='HomePlanet')
# Out:
# <AxesSubplot:xlabel='Destination', ylabel='count'>

# %%
sns.countplot(data=df, x='HomePlanet', hue='Destination')
# Out:
# <AxesSubplot:xlabel='HomePlanet', ylabel='count'>

# %%
sns.countplot(data=df, x='CryoSleep', hue='HomePlanet')
# Out:
# <AxesSubplot:xlabel='CryoSleep', ylabel='count'>

# %%
df['Destination'].fillna(df[df['HomePlanet']=='Europa']['Destination'].mode()[0])

# %%
df[df['HomePlanet']=='Europa']['Destination'].mode()[0]
# Out:
# 'TRAPPIST-1e'

# %%
df[(df['Destination'].isna()) & (df['HomePlanet'].isna())]
# Out:
#      PassengerId CryoSleep     Cabin Destination   Age    VIP  RoomService  \
# 347      0382_01     False    G/64/P         NaN  23.0  False        348.0
# 5208     5555_01     False   G/896/S         NaN  43.0    NaN          1.0
# 5687     6031_01     False  F/1146/S         NaN  52.0  False          0.0
#
#       FoodCourt  ShoppingMall  Spa  ...  Deck Num_cb Side  Name_1  \
# 347         0.0           0.0  4.0  ...     G     64    P  Blanie
# 5208        0.0         213.0  7.0  ...     G    896    S   Winia
# 5687      645.0           0.0  0.0  ...     F   1146    S  Bobara
#
#            Name_2 Name_len Name_1_len Name_2_len N1_1ch N2_1ch
# 347   Floydendley       18          6         11      B      F
# 5208   Blanglison       16          5         10      W      B
# 5687    Alshipson       16          6          9      B      A
#
# [3 rows x 26 columns]

# %%
df[(df['Destination'].notnull()) & (df['HomePlanet'].isna())]
# Out:
#       PassengerId CryoSleep     Cabin    Destination   Age    VIP  \
# 186       0210_01      True     D/6/P    55 Cancri e  24.0  False
# 225       0242_01     False    F/46/S    TRAPPIST-1e  18.0  False
# 234       0251_01      True    C/11/S    55 Cancri e  54.0  False
# 274       0303_01      True    G/41/S    TRAPPIST-1e  23.0  False
# 286       0315_01      True    G/42/S  PSO J318.5-22  35.0  False
# ...           ...       ...       ...            ...   ...    ...
# 12542     8417_01     False  F/1617/S    TRAPPIST-1e  43.0  False
# 12551     8435_01       NaN  F/1730/P    TRAPPIST-1e  19.0  False
# 12638     8576_01      True   C/322/S    55 Cancri e  25.0  False
# 12650     8621_01     False   E/552/P    TRAPPIST-1e  19.0  False
# 12725     8775_01      True   D/275/P    TRAPPIST-1e  40.0  False
#
#        RoomService  FoodCourt  ShoppingMall    Spa  ...  Deck Num_cb Side  \
# 186            0.0        0.0           NaN    0.0  ...     D      6    P
# 225          313.0        1.0         691.0  283.0  ...     F     46    S
# 234            0.0        0.0           0.0    0.0  ...     C     11    S
# 274            0.0        0.0           0.0    0.0  ...     G     41    S
# 286            0.0        0.0           0.0    0.0  ...     G     42    S
# ...            ...        ...           ...    ...  ...   ...    ...  ...
# 12542          0.0        0.0         775.0    0.0  ...     F   1617    S
# 12551        162.0       11.0           0.0    0.0  ...     F   1730    P
# 12638          0.0        NaN           0.0    0.0  ...     C    322    S
# 12650          4.0        0.0        1604.0    0.0  ...     E    552    P
# 12725          0.0        0.0           0.0    0.0  ...     D    275    P
#
#        Name_1      Name_2 Name_len Name_1_len Name_2_len N1_1ch N2_1ch
# 186    Arraid     Inicont       14          6          7      A      I
# 225    Almone         Sté       10          6          3      A      S
# 234    Diphah      Amsive       13          6          6      D      A
# 274    Oraryn  Kirklander       17          6         10      O      K
# 286    Adriet   Valezaley       16          6          9      A      V
# ...       ...         ...      ...        ...        ...    ...    ...
# 12542   Luzel  Bertsontry       16          5         10      L      B
# 12551    None        None        9          4          4      N      N
# 12638  Skatzn      Catbel       13          6          6      S      C
# 12650  Vanley  Simmonders       17          6         10      V      S
# 12725  Raston   Maltorted       16          6          9      R      M
#
# [154 rows x 26 columns]

# %%
df[(df['Destination'].isna()) & (df['HomePlanet'].notnull())]
# Out:
#       PassengerId CryoSleep     Cabin Destination   Age    VIP  RoomService  \
# 47        0045_02      True    F/10/P         NaN  19.0  False          0.0
# 128       0138_02     False     E/5/P         NaN  34.0  False          0.0
# 139       0152_01     False    F/32/P         NaN  41.0  False          0.0
# 430       0462_01      True    G/67/S         NaN  50.0  False          0.0
# 468       0504_03      True    B/19/S         NaN  24.0  False          0.0
# ...           ...       ...       ...         ...   ...    ...          ...
# 12851     9022_03      True  F/1748/S         NaN   0.0  False          0.0
# 12856     9039_01      True  G/1468/P         NaN  23.0  False          0.0
# 12889     9095_01     False  G/1478/P         NaN  31.0  False          0.0
# 12912     9155_01     False   C/304/P         NaN  17.0  False        149.0
# 12968     9273_01     False   D/297/P         NaN   NaN  False          0.0
#
#        FoodCourt  ShoppingMall     Spa  ...  Deck Num_cb Side   Name_1  \
# 47           0.0           0.0     0.0  ...     F     10    P     Mass
# 128         22.0           0.0   564.0  ...     E      5    P    Monah
# 139          0.0           0.0     0.0  ...     F     32    P    Andan
# 430          0.0           0.0     0.0  ...     G     67    S    Ronia
# 468          0.0           0.0     0.0  ...     B     19    S  Sterops
# ...          ...           ...     ...  ...   ...    ...  ...      ...
# 12851        0.0           0.0     0.0  ...     F   1748    S    Erice
# 12856        0.0           0.0     0.0  ...     G   1468    P    Nance
# 12889        0.0           NaN     0.0  ...     G   1478    P    Lelah
# 12912     2045.0           NaN  1872.0  ...     C    304    P   Markar
# 12968     2680.0           0.0     0.0  ...     D    297    P  Kitakan
#
#             Name_2 Name_len Name_1_len Name_2_len N1_1ch N2_1ch
# 47           Chmad       10          4          5      M      C
# 128          Gambs       11          5          5      M      G
# 139         Estron       12          5          6      A      E
# 430    Sosanturney       17          5         11      R      S
# 468       Unpasine       16          7          8      S      U
# ...            ...      ...        ...        ...    ...    ...
# 12851     Boyerson       14          5          8      E      B
# 12856    Wilkinner       15          5          9      N      W
# 12889    Reynoldez       15          5          9      L      R
# 12912     Amoutake       15          6          8      M      A
# 12968       Conale       14          7          6      K      C
#
# [271 rows x 26 columns]
